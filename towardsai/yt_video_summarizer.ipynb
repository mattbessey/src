# %%
import yt_dlp

# %%
def download_mp4_from_yt(url, filename):
    filename = filename + '.mp4'
    ydl_opts = {
        'format': 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/best[ext=mp4]/best',
        'outtmpl': filename,
        'quiet': True,
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        result = ydl.extract_info(url, download=True)

# %%
url = "https://www.youtube.com/watch?v=mBjPyte2ZZo"
filename = 'lecuninterview'
download_mp4_from_yt(url, filename)
# Out:
# ERROR: You have requested merging of multiple formats but ffmpeg is not installed. Aborting due to --abort-on-error
# ---------------------------------------------------------------------------
# DownloadError                             Traceback (most recent call last)
# Cell In[6], line 3
#       1 url = "https://www.youtube.com/watch?v=mBjPyte2ZZo"
#       2 filename = 'lecuninterview'
# ----> 3 download_mp4_from_yt(url, filename)
#
# Cell In[5], line 10, in download_mp4_from_yt(url, filename)
#       3 ydl_opts = {
#       4     'format': 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/best[ext=mp4]/best',
#       5     'outtmpl': filename,
#       6     'quiet': True,
#       7 }
#       9 with yt_dlp.YoutubeDL(ydl_opts) as ydl:
# ---> 10     result = ydl.extract_info(url, download=True)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/python3.12/lib/python3.12/site-packages/yt_dlp/YoutubeDL.py:1623, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1621             raise ExistingVideoReached
#    1622         break
# -> 1623     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1624 else:
#    1625     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/python3.12/lib/python3.12/site-packages/yt_dlp/YoutubeDL.py:1634, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1632 while True:
#    1633     try:
# -> 1634         return func(self, *args, **kwargs)
#    1635     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1636         raise
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/python3.12/lib/python3.12/site-packages/yt_dlp/YoutubeDL.py:1790, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1788 if process:
#    1789     self._wait_for_video(ie_result)
# -> 1790     return self.process_ie_result(ie_result, download, extra_info)
#    1791 else:
#    1792     return ie_result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/python3.12/lib/python3.12/site-packages/yt_dlp/YoutubeDL.py:1849, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1847 if result_type == 'video':
#    1848     self.add_extra_info(ie_result, extra_info)
# -> 1849     ie_result = self.process_video_result(ie_result, download=download)
#    1850     self._raise_pending_errors(ie_result)
#    1851     additional_urls = (ie_result or {}).get('additional_urls')
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/python3.12/lib/python3.12/site-packages/yt_dlp/YoutubeDL.py:3021, in YoutubeDL.process_video_result(self, info_dict, download)
#    3019 downloaded_formats.append(new_info)
#    3020 try:
# -> 3021     self.process_info(new_info)
#    3022 except MaxDownloadsReached:
#    3023     max_downloads_reached = True
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/python3.12/lib/python3.12/site-packages/yt_dlp/YoutubeDL.py:177, in _catch_unsafe_extension_error.<locals>.wrapper(self, *args, **kwargs)
#     174 @functools.wraps(func)
#     175 def wrapper(self, *args, **kwargs):
#     176     try:
# --> 177         return func(self, *args, **kwargs)
#     178     except _UnsafeExtensionError as error:
#     179         self.report_error(
#     180             f'The extracted extension ({error.extension!r}) is unusual '
#     181             'and will be skipped for safety reasons. '
#     182             f'If you believe this is an error{bug_reports_message(",")}')
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/python3.12/lib/python3.12/site-packages/yt_dlp/YoutubeDL.py:3447, in YoutubeDL.process_info(self, info_dict)
#    3445 msg = 'You have requested merging of multiple formats but ffmpeg is not installed'
#    3446 if not self.params.get('ignoreerrors'):
# -> 3447     self.report_error(f'{msg}. Aborting due to --abort-on-error')
#    3448     return
#    3449 self.report_warning(f'{msg}. The formats won\'t be merged')
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/python3.12/lib/python3.12/site-packages/yt_dlp/YoutubeDL.py:1092, in YoutubeDL.report_error(self, message, *args, **kwargs)
#    1087 def report_error(self, message, *args, **kwargs):
#    1088     """
#    1089     Do the same as trouble, but prefixes the message with 'ERROR:', colored
#    1090     in red if stderr is a tty file.
#    1091     """
# -> 1092     self.trouble(f'{self._format_err("ERROR:", self.Styles.ERROR)} {message}', *args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/python3.12/lib/python3.12/site-packages/yt_dlp/YoutubeDL.py:1031, in YoutubeDL.trouble(self, message, tb, is_error)
#    1029     else:
#    1030         exc_info = sys.exc_info()
# -> 1031     raise DownloadError(message, exc_info)
#    1032 self._download_retcode = 1
#
# DownloadError: ERROR: You have requested merging of multiple formats but ffmpeg is not installed. Aborting due to --abort-on-error
